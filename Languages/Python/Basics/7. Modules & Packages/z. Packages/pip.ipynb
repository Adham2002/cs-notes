# %%
#######
# Pip #
#######

# Install package
# %pip install matplotlib
# %pip install matplotlib==3.8.0
# %pip install -r virtual_environments.txt 

# Update package
# %pip install matplotlib -U

# Uninstall package
# %pip uninstall matplotlib
# %pip uninstall -r virtual_environments.txt
